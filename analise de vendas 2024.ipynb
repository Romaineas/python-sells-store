# %%
import pandas as pd

# %%
df= pd.read_excel("Vendas (1).xlsx")
df.head()
# Out:
#         Data             ID Loja           Produto  Quantidade  \
# 0 2019-12-01   Iguatemi Campinas   Bermuda Estampa           1
# 1 2019-12-01  Iguatemi Esplanada    Bermuda Xadrez           1
# 2 2019-12-01      Norte Shopping           Bermuda           2
# 3 2019-12-01   Iguatemi Campinas  Bermuda Listrado           3
# 4 2019-12-01   Iguatemi Campinas     Bermuda Linho           3
#
#    Valor Unitário  Valor Final
# 0             169          169
# 1             155          155
# 2             150          300
# 3             163          489
# 4             195          585

# %%
df.isnull().sum()
df.describe()
# Out:
#        Quantidade  Valor Unitário   Valor Final
# count   57.000000       57.000000     57.000000
# mean     6.140351      164.210526    980.614035
# std     17.577826       14.011139   2757.203926
# min      1.000000      150.000000    150.000000
# 25%      1.000000      155.000000    163.000000
# 50%      2.000000      163.000000    310.000000
# 75%      4.000000      169.000000    600.000000
# max    100.000000      195.000000  15700.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Summarizing data by product
product_sums = df.groupby('Produto')['Quantidade'].sum().reset_index()

# Plotting the bar graph
plt.figure(figsize=(10, 8))
sns.barplot(x='Produto', y='Quantidade', data=product_sums, palette="viridis")

plt.title('Quantidade by Produto')
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.tight_layout()
plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# masterDisciplines = df['Quantidade', 'Produto']
# plt.figure(figsize=(10, 8))
# plt.tight_layout()
# sns.countplot(masterDisciplines)
# plt.title('distribuição Vendas por loja')
# plt.show()




import seaborn as sns
import matplotlib.pyplot as plt

# Select the desired columns
masterDisciplines = df[['Quantidade', 'ID Loja']]

# Plotting (example using seaborn)
plt.figure(figsize=(10, 8))
sns.barplot(data=masterDisciplines, x='ID Loja', y='Quantidade')
plt.tight_layout()
plt.show()

# %%
pivot_table = df.pivot_table(index='Produto', values='Valor Unitário', aggfunc='sum')

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", cbar=True)

plt.title('Heatmap de Quantidade por Valor unitário')
plt.xlabel('Valor Unitário')
plt.ylabel('Produto')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Produto', y='Quantidade', hue='ID Loja', data=df, palette="viridis")

plt.title('Quantity by Product and Store ID')
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.legend(title='ID Loja')
plt.tight_layout()
plt.show()
